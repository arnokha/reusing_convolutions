# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns

sns.set()

# %%
atari_games_list = [
    "Alien",
    "Amidar",
    "Assault",
    "Asterix",
    "BankHeist",
    "BattleZone",
    "Boxing",
    "Breakout",
    "ChopperCommand",
    "CrazyClimber",
    "DemonAttack",
    "Freeway",
    "Gopher",
    "Hero",
    "Kangaroo",
    "Krull",
    "KungFuMaster",
    "MsPacman",
    "Pong",
    "PrivateEye",
    "Qbert",
    "RoadRunner",
    "YarsRevenge",
    "Seaquest"
]

# %%
def extract_avg(f):
    with open(f) as f:
        first_line = f.readline()
        return float(first_line.rsplit(" ")[-1])

# %%
results_10_20 = {}
results_20_40 = {}
results_40_80 = {}
results_80_160 = {}
DIRS = ["./BASE_CPU/", "./REUSE_CPU/", "./BASE_GPU/", "./REUSE_GPU/"]
aliases = ["base_cpu", "reuse_cpu", "base_gpu", "reuse_gpu"]

#DIRS = ["./BASE_CPU/", "./REUSE_CPU/", "./BASE_GPU/"]
#aliases = ["base_cpu", "reuse_cpu", "base_gpu"]

games_results_not_complete = []

for game in atari_games_list:
    results_10_20[game] = []
    results_20_40[game] = []
    results_40_80[game] = []
    results_80_160[game] = []
    
for DIR, alias in zip(DIRS, aliases):
    dir_cont = sorted(os.listdir(DIR))
    #print(DIR)
    
    for game in dir_cont: ## Each game is a dir name
        
        ## Skip any non-directory files
        if ".sh" in game or ".py" in game or ".ipynb" in game:
            continue
        
        ## Get result file from sub directory
        full_path = DIR + game
        result_files = os.listdir(full_path)
        #print(DIR, game, result_files)
        
        ## Detect missing results
        if len(result_files) < 4:
            print("No results for: " + full_path.rsplit("/")[-1] + " ("+DIR+")")
            print("Missing " + str(4 - len(result_files)))
            print(not np.nan in results_80_160[game], results_80_160[game])
            games_results_not_complete.append(full_path.rsplit("/")[-1])
            if len(result_files) == 3: # and not np.nan in results_80_160[game]:
                print("Missing 1")
                results_80_160[game].append(np.nan)
            elif len(result_files) == 2: # and not np.nan in results_80_160[game]:
                print("Missing 2")
                results_40_80[game].append(np.nan)
                results_80_160[game].append(np.nan)
            elif len(result_files) == 1: # and not np.nan in results_80_160[game]:
                print("Missing 3")
                results_20_40[game].append(np.nan)
                results_40_80[game].append(np.nan)
                results_80_160[game].append(np.nan)
            #elif len(result_files) < 2:
            #    print("Missing 3!")
            #    print(len(result_files))
            #continue

        ## Now we are looking at the result of a particular game using a particular method/hardware
        #results[(alias, game)] = extract_avg(full_path + "/" + result_file[0])
        for result_file in result_files:
            #print(result_file)
            if "10_20" in result_file:
                results_10_20[game].append(extract_avg(full_path + "/" + result_file))
            elif "20_40" in result_file:
                results_20_40[game].append(extract_avg(full_path + "/" + result_file))
            elif "40_80" in result_file:
                results_40_80[game].append(extract_avg(full_path + "/" + result_file))
            elif "80_160" in result_file:
                results_80_160[game].append(extract_avg(full_path + "/" + result_file))
# Out:
# No results for: Alien (./BASE_CPU/)
# Missing 3
# True []
# Missing 3
# No results for: Amidar (./BASE_CPU/)
# Missing 3
# True []
# Missing 3
# No results for: Assault (./BASE_CPU/)
# Missing 3
# True []
# Missing 3
# No results for: Asterix (./BASE_CPU/)
# Missing 3
# True []
# Missing 3
# No results for: BankHeist (./BASE_CPU/)
# Missing 3
# True []
# Missing 3
# No results for: BattleZone (./BASE_CPU/)
# Missing 3
# True []
# Missing 3
# No results for: Boxing (./BASE_CPU/)
# Missing 3
# True []
# Missing 3
# No results for: Breakout (./BASE_CPU/)
# Missing 3
# True []
# Missing 3
# No results for: ChopperCommand (./BASE_CPU/)
# Missing 3
# True []
# Missing 3
# No results for: CrazyClimber (./BASE_CPU/)
# Missing 2
# True []
# Missing 2
# No results for: DemonAttack (./BASE_CPU/)
# Missing 2
# True []
# Missing 2
# No results for: Freeway (./BASE_CPU/)
# Missing 2
# True []
# Missing 2
# No results for: Gopher (./BASE_CPU/)
# Missing 2
# True []
# Missing 2
# No results for: Hero (./BASE_CPU/)
# Missing 2
# True []
# Missing 2
# No results for: Kangaroo (./BASE_CPU/)
# Missing 2
# True []
# Missing 2
# No results for: Krull (./BASE_CPU/)
# Missing 2
# True []
# Missing 2
# No results for: KungFuMaster (./BASE_CPU/)
# Missing 2
# True []
# Missing 2
# No results for: MsPacman (./BASE_CPU/)
# Missing 2
# True []
# Missing 2
# No results for: Pong (./BASE_CPU/)
# Missing 2
# True []
# Missing 2
# No results for: PrivateEye (./BASE_CPU/)
# Missing 2
# True []
# Missing 2
# No results for: Qbert (./BASE_CPU/)
# Missing 2
# True []
# Missing 2
# No results for: RoadRunner (./BASE_CPU/)
# Missing 2
# True []
# Missing 2
# No results for: Seaquest (./BASE_CPU/)
# Missing 2
# True []
# Missing 2
# No results for: YarsRevenge (./BASE_CPU/)
# Missing 2
# True []
# Missing 2
# No results for: Alien (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: Amidar (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: Assault (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: Asterix (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: BankHeist (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: BattleZone (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: Boxing (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: Breakout (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: ChopperCommand (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: CrazyClimber (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: DemonAttack (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: Freeway (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: Gopher (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: Hero (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: Kangaroo (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: Krull (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: KungFuMaster (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: MsPacman (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: Pong (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: PrivateEye (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: Qbert (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: RoadRunner (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: Seaquest (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: YarsRevenge (./REUSE_CPU/)
# Missing 2
# False [nan]
# Missing 2
# No results for: Alien (./BASE_GPU/)
# Missing 2
# False [nan, nan]
# Missing 2
# No results for: Amidar (./BASE_GPU/)
# Missing 3
# False [nan, nan]
# Missing 3
# No results for: Assault (./BASE_GPU/)
# Missing 4
# False [nan, nan]
# No results for: Asterix (./BASE_GPU/)
# Missing 4
# False [nan, nan]
# No results for: BankHeist (./BASE_GPU/)
# Missing 4
# False [nan, nan]
# No results for: BattleZone (./BASE_GPU/)
# Missing 4
# False [nan, nan]
# No results for: Boxing (./BASE_GPU/)
# Missing 4
# False [nan, nan]
# No results for: Breakout (./BASE_GPU/)
# Missing 4
# False [nan, nan]
# No results for: ChopperCommand (./BASE_GPU/)
# Missing 3
# False [nan, nan]
# Missing 3
# No results for: CrazyClimber (./BASE_GPU/)
# Missing 3
# False [nan, nan]
# Missing 3
# No results for: DemonAttack (./BASE_GPU/)
# Missing 3
# False [nan, nan]
# Missing 3
# No results for: Freeway (./BASE_GPU/)
# Missing 3
# False [nan, nan]
# Missing 3
# No results for: Gopher (./BASE_GPU/)
# Missing 3
# False [nan, nan]
# Missing 3
# No results for: Hero (./BASE_GPU/)
# Missing 3
# False [nan, nan]
# Missing 3
# No results for: Kangaroo (./BASE_GPU/)
# Missing 2
# False [nan, nan]
# Missing 2
# No results for: Krull (./BASE_GPU/)
# Missing 3
# False [nan, nan]
# Missing 3
# No results for: KungFuMaster (./BASE_GPU/)
# Missing 2
# False [nan, nan]
# Missing 2
# No results for: MsPacman (./BASE_GPU/)
# Missing 2
# False [nan, nan]
# Missing 2
# No results for: Pong (./BASE_GPU/)
# Missing 2
# False [nan, nan]
# Missing 2
# No results for: PrivateEye (./BASE_GPU/)
# Missing 3
# False [nan, nan]
# Missing 3
# No results for: Qbert (./BASE_GPU/)
# Missing 2
# False [nan, nan]
# Missing 2
# No results for: RoadRunner (./BASE_GPU/)
# Missing 2
# False [nan, nan]
# Missing 2
# No results for: Seaquest (./BASE_GPU/)
# Missing 3
# False [nan, nan]
# Missing 3
# No results for: YarsRevenge (./BASE_GPU/)
# Missing 3
# False [nan, nan]
# Missing 3
# No results for: Alien (./REUSE_GPU/)
# Missing 1
# False [nan, nan, nan]
# Missing 1
# No results for: Amidar (./REUSE_GPU/)
# Missing 1
# False [nan, nan, nan]
# Missing 1
# No results for: Assault (./REUSE_GPU/)
# Missing 3
# False [nan, nan]
# Missing 3
# No results for: Asterix (./REUSE_GPU/)
# Missing 1
# False [nan, nan]
# Missing 1
# No results for: BankHeist (./REUSE_GPU/)
# Missing 2
# False [nan, nan]
# Missing 2
# No results for: BattleZone (./REUSE_GPU/)
# Missing 2
# False [nan, nan]
# Missing 2
# No results for: Boxing (./REUSE_GPU/)
# Missing 1
# False [nan, nan]
# Missing 1
# No results for: Breakout (./REUSE_GPU/)
# Missing 1
# False [nan, nan]
# Missing 1
# No results for: ChopperCommand (./REUSE_GPU/)
# Missing 2
# False [nan, nan, nan]
# Missing 2
# No results for: CrazyClimber (./REUSE_GPU/)
# Missing 1
# False [nan, nan, nan]
# Missing 1
# No results for: DemonAttack (./REUSE_GPU/)
# Missing 2
# False [nan, nan, nan]
# Missing 2
# No results for: Freeway (./REUSE_GPU/)
# Missing 3
# False [nan, nan, nan]
# Missing 3
# No results for: Hero (./REUSE_GPU/)
# Missing 2
# False [nan, nan, nan]
# Missing 2
# No results for: Krull (./REUSE_GPU/)
# Missing 2
# False [nan, nan, nan]
# Missing 2
# No results for: KungFuMaster (./REUSE_GPU/)
# Missing 1
# False [nan, nan, nan]
# Missing 1
# No results for: MsPacman (./REUSE_GPU/)
# Missing 1
# False [nan, nan, nan]
# Missing 1
# No results for: Pong (./REUSE_GPU/)
# Missing 1
# False [nan, nan, nan]
# Missing 1
# No results for: PrivateEye (./REUSE_GPU/)
# Missing 2
# False [nan, nan, nan]
# Missing 2
# No results for: RoadRunner (./REUSE_GPU/)
# Missing 1
# False [nan, nan, nan]
# Missing 1
# No results for: Seaquest (./REUSE_GPU/)
# Missing 2
# False [nan, nan, nan]
# Missing 2
# No results for: YarsRevenge (./REUSE_GPU/)
# Missing 2
# False [nan, nan, nan]
# Missing 2

# %%
## Averages over 10 runs. First element is from base_cpu, second from reuse_cpu, third from base_gpu
## Things to notice: 
## (1) Each run has high variance because these episode lengths can vary greatly, and number of .
##     whcih means there can be a variable number of backpropagations.
## (2) The worst performance of reuse comes from games with large areas of pixel change 
##       (BattleZone, ChopperCommand, Freeway, Krull, MsPacman, YarsRevenge)
## (3) Get's a very big performance boost on games that have little pixel change from frame to frame
##     (Amidar, Breakout, CrazyClimber, Gopher, Hero, Kangaroo, KungFuMaster, 
##      Pong, PrivateEye, Qbert)
## (4) There were games where the CPU version of reuse was faster than the GPU base version
## (5) Not immediately obvious why it performed much more poorly than base CPU on RoadRunner, Seaquest

print(results_10_20)
print()

print(results_20_40)
print()
print(results_40_80)
print()
print(results_80_160)
# Out:
# {'Alien': [20.44, 17.79, 6.85], 'Kangaroo': [20.53, 14.11, 6.27, 5.55], 'Boxing': [18.49, 14.39, 6.24], 'BankHeist': [16.89, 12.38, 6.23], 'Pong': [10.49, 6.45, 5.47, 5.85], 'Hero': [10.67, 5.95, 4.93, 4.99], 'DemonAttack': [7.53, 3.86, 4.38, 5.04], 'Gopher': [13.38, 7.32, 6.13, 5.75], 'Amidar': [18.32, 11.52, 6.2], 'CrazyClimber': [5.58, 2.19, 3.96, 4.24], 'BattleZone': [15.54, 15.44, 6.73], 'Breakout': [6.2, 2.28, 4.32], 'Freeway': [11.16, 11.28, 6.29, 6.86], 'Krull': [10.57, 10.4, 5.35, 5.88], 'YarsRevenge': [17.65, 13.81, 5.51, 6.18], 'MsPacman': [14.99, 12.33, 6.04, 6.28], 'Seaquest': [10.22, 7.48, 4.94, 5.3], 'Assault': [13.2, 8.89, 6.77], 'Qbert': [12.73, 8.43, 5.87, 6.15], 'KungFuMaster': [17.26, 12.03, 6.43, 6.1], 'Asterix': [13.66, 10.51, 5.72], 'RoadRunner': [21.24, 16.37, 6.45, 6.07], 'PrivateEye': [6.72, 4.17, 4.39, 5.04], 'ChopperCommand': [18.67, 17.32, 6.31]}
#
# {'Alien': [nan, 34.25, 9.73, 9.98], 'Kangaroo': [42.61, 28.4, 9.68, 8.41], 'Boxing': [nan, 26.1, 9.1], 'BankHeist': [nan, 16.06, 9.49], 'Pong': [21.59, 11.55, 8.47, 8.3], 'Hero': [16.94, 8.04, nan, 7.57], 'DemonAttack': [16.0, 9.64, nan, 7.46], 'Gopher': [29.62, 12.66, nan, 8.63], 'Amidar': [nan, 21.24, nan, 10.83, 9.63], 'CrazyClimber': [12.47, 4.13, nan, 6.38], 'BattleZone': [nan, 31.32, 9.44], 'Breakout': [nan, 3.88, 6.78], 'Freeway': [23.22, 22.02, nan, nan], 'Krull': [26.05, 23.68, nan, 8.42], 'YarsRevenge': [33.09, 31.14, nan, 8.91], 'MsPacman': [30.61, 24.61, 9.02, 9.09], 'Seaquest': [14.1, 12.45, nan, 7.91], 'Assault': [nan, 23.32, nan], 'Qbert': [24.8, 14.96, 9.12, 8.77], 'KungFuMaster': [36.39, 23.03, 9.78, 8.97], 'Asterix': [nan, 21.05, 8.52], 'RoadRunner': [43.52, 29.85, 9.88, 8.79], 'PrivateEye': [12.35, 6.44, nan, 7.35], 'ChopperCommand': [nan, 32.92, nan, 9.88, 9.92]}
#
# {'Alien': [nan, nan, nan, 15.97, 15.78], 'Kangaroo': [nan, nan, nan, 14.06], 'Boxing': [nan, nan, 14.73], 'BankHeist': [nan, nan, nan], 'Pong': [nan, nan, nan, 13.52], 'Hero': [nan, nan, nan, nan], 'DemonAttack': [nan, nan, nan, nan], 'Gopher': [nan, nan, nan, 15.35], 'Amidar': [nan, nan, nan, 15.83], 'CrazyClimber': [nan, nan, nan, 11.31], 'BattleZone': [nan, nan, nan], 'Breakout': [nan, nan, 11.57], 'Freeway': [nan, nan, nan, nan], 'Krull': [nan, nan, nan, nan], 'YarsRevenge': [nan, nan, nan, nan], 'MsPacman': [nan, nan, nan, 14.49], 'Seaquest': [nan, nan, nan, nan], 'Assault': [nan, nan, nan], 'Qbert': [nan, nan, nan, 14.03], 'KungFuMaster': [nan, nan, nan, 14.85], 'Asterix': [nan, nan, 13.9], 'RoadRunner': [nan, nan, nan, 14.28], 'PrivateEye': [nan, nan, nan, nan], 'ChopperCommand': [nan, nan, nan, nan]}
#
# {'Alien': [nan, nan, nan, nan], 'Kangaroo': [nan, nan, nan, 25.86], 'Boxing': [nan, nan, nan], 'BankHeist': [nan, nan, nan], 'Pong': [nan, nan, nan, nan], 'Hero': [nan, nan, nan, nan], 'DemonAttack': [nan, nan, nan, nan], 'Gopher': [nan, nan, nan, 28.37], 'Amidar': [nan, nan, nan, nan], 'CrazyClimber': [nan, nan, nan, nan], 'BattleZone': [nan, nan, nan], 'Breakout': [nan, nan, nan], 'Freeway': [nan, nan, nan, nan], 'Krull': [nan, nan, nan, nan], 'YarsRevenge': [nan, nan, nan, nan], 'MsPacman': [nan, nan, nan, nan], 'Seaquest': [nan, nan, nan, nan], 'Assault': [nan, nan, nan], 'Qbert': [nan, nan, nan, 25.04], 'KungFuMaster': [nan, nan, nan, nan], 'Asterix': [nan, nan, nan], 'RoadRunner': [nan, nan, nan, nan], 'PrivateEye': [nan, nan, nan, nan], 'ChopperCommand': [nan, nan, nan, nan]}

# %%
#df = pd.DataFrame(results, index=atari_games_list)
df_10_20 = pd.DataFrame(results_10_20, index=aliases)
df_20_40 = pd.DataFrame(results_20_40, index=aliases)
df_40_80 = pd.DataFrame(results_40_80, index=aliases)
df_80_160 = pd.DataFrame(results_80_160, index=aliases)
#df.columns = pd.MultiIndex.from_tuples(tuples)

# %%
#df = pd.DataFrame(results)

# %%
df_20_40
# Out:
#            Alien  Amidar  Assault  Asterix  BankHeist  BattleZone  Boxing  \
# base_cpu   42.82   34.80    28.89    29.15      51.96       36.24   37.62
# reuse_cpu  34.27   21.01    23.19    20.94      16.01       31.00   26.19
# base_gpu    9.68   10.80     3.54     3.85       3.88        3.69    4.40
#
#            Breakout  ChopperCommand  CrazyClimber     ...       Kangaroo  \
# base_cpu      13.43           39.92         12.46     ...          42.48
# reuse_cpu      3.85           32.82          4.06     ...          28.08
# base_gpu       3.07            9.86          2.87     ...           9.71
#
#            Krull  KungFuMaster  MsPacman   Pong  PrivateEye  Qbert  \
# base_cpu   26.12         36.30     30.49  21.45       12.48  24.66
# reuse_cpu  23.64         22.79     24.39  11.43        6.37  14.89
# base_gpu    3.85          9.80      9.06   9.89        3.05   9.13
#
#            RoadRunner  Seaquest  YarsRevenge
# base_cpu        43.02     14.09        32.98
# reuse_cpu       29.69     12.34        31.12
# base_gpu         9.88      3.32         4.10
#
# [3 rows x 24 columns]

# %%
df_80_160.fillna("-")
# Out:
#             Alien  Amidar Assault Asterix BankHeist BattleZone  Boxing  \
# base_cpu   410.69  783.82   39.23    43.7     33.94      48.67   50.22
# reuse_cpu  160.54   98.74   24.79  102.74     92.74    1016.77  108.67
# base_gpu     9.24    9.71       -       -         -          -       -
#
#           Breakout ChopperCommand CrazyClimber     ...     Kangaroo   Krull  \
# base_cpu     27.44         387.95        18.27     ...       234.24   32.97
# reuse_cpu    20.56         181.04        14.39     ...       117.66  515.34
# base_gpu         -              -            -     ...         8.82       -
#
#           KungFuMaster MsPacman    Pong PrivateEye   Qbert  RoadRunner  \
# base_cpu         602.2   190.38  558.71      20.03  207.90      386.88
# reuse_cpu        98.53   123.80   48.25       52.9   76.60      131.77
# base_gpu             -     8.33    7.88          -    8.24           -
#
#            Seaquest YarsRevenge
# base_cpu      28.64       44.31
# reuse_cpu    137.59      479.02
# base_gpu          -           -
#
# [3 rows x 24 columns]

# %%
#df.to_html('training_table_by_episode_20_40_3000_steps.html')

# %%
## New table - Computational savings from base cpu to reuse cpu, and base gpu to reuse cpu, and add row that has average

# %%
df_10_20 = df_10_20.T

df_10_20["reuse_cpu/base_cpu"] = (df_10_20["reuse_cpu"] / df_10_20["base_cpu"]).round(decimals=2)
df_10_20["reuse_cpu/base_gpu"] = (df_10_20["reuse_cpu"] / df_10_20["base_gpu"]).round(decimals=2)
df_10_20["base_cpu/base_gpu"] = (df_10_20["base_cpu"] / df_10_20["base_gpu"]).round(decimals=2)

df_10_20 = df_10_20.T
df_10_20["Mean"] = df_10_20.T.mean()

df_10_20.round(2).to_html('training_table_by_episode_10_20_3000_steps_more_info.html')
df_10_20.T.round(2).to_html('training_table_by_episode_10_20_3000_steps_more_info_T.html')

# %%
df_20_40 = df_20_40.T

df_20_40["reuse_cpu/base_cpu"] = (df_20_40["reuse_cpu"] / df_20_40["base_cpu"]).round(decimals=2)
df_20_40["reuse_cpu/base_gpu"] = (df_20_40["reuse_cpu"] / df_20_40["base_gpu"]).round(decimals=2)
df_20_40["base_cpu/base_gpu"] = (df_20_40["base_cpu"] / df_20_40["base_gpu"]).round(decimals=2)

df_20_40 = df_20_40.T
df_20_40["Mean"] = df_20_40.T.mean()

df_20_40.round(2).fillna("-").to_html('training_table_by_episode_20_40_3000_steps_more_info.html')
df_20_40.T.round(2).fillna("-").to_html('training_table_by_episode_20_40_3000_steps_more_info_T.html')

# %%
df_40_80 = df_40_80.T

df_40_80["reuse_cpu/base_cpu"] = (df_40_80["reuse_cpu"] / df_40_80["base_cpu"]).round(decimals=2)
df_40_80["reuse_cpu/base_gpu"] = (df_40_80["reuse_cpu"] / df_40_80["base_gpu"]).round(decimals=2)
df_40_80["base_cpu/base_gpu"] = (df_40_80["base_cpu"] / df_40_80["base_gpu"]).round(decimals=2)

df_40_80 = df_40_80.T
df_40_80["Mean"] = df_40_80.T.mean()

df_40_80.round(2).fillna("-").to_html('training_table_by_episode_40_80_3000_steps_more_info.html')
df_40_80.T.round(2).fillna("-").to_html('training_table_by_episode_40_80_3000_steps_more_info_T.html')

# %%
df_80_160 = df_80_160.T

df_80_160["reuse_cpu/base_cpu"] = (df_80_160["reuse_cpu"] / df_80_160["base_cpu"]).round(decimals=2)
df_80_160["reuse_cpu/base_gpu"] = (df_80_160["reuse_cpu"] / df_80_160["base_gpu"]).round(decimals=2)
df_80_160["base_cpu/base_gpu"] = (df_80_160["base_cpu"] / df_80_160["base_gpu"]).round(decimals=2)

df_80_160 = df_80_160.T
df_80_160["Mean"] = df_80_160.T.mean()

df_80_160.round(2).fillna("-").to_html('training_table_by_episode_80_160_3000_steps_more_info.html')
df_80_160.T.round(2).fillna("-").to_html('training_table_by_episode_80_160_3000_steps_more_info_T.html')

# %%
df = df.T

# %%
df["reuse_cpu/base_cpu"] = (df["reuse_cpu"] / df["base_cpu"]).round(decimals=2)

df["reuse_cpu/base_gpu"] = (df["reuse_cpu"] / df["base_gpu"]).round(decimals=2)

df["base_cpu/base_gpu"] = (df["base_cpu"] / df["base_gpu"]).round(decimals=2)

# %%
df = df.round(decimals=2).T

# %%
df["Mean"] = df.T.mean()

# %%
df["Mean"]
# Out:
# base_cpu              7.109583
# reuse_cpu             5.567500
# base_gpu              3.862917
# reuse_cpu/base_cpu    0.772500
# reuse_cpu/base_gpu    1.408333
# base_cpu/base_gpu     1.805417
# Name: Mean, dtype: float64

# %%
df.round(2).to_html('training_table_by_episode_20_40_conv_3000_steps_more_info.html')

# %%
df.T.round(2).to_html('training_table_by_episode_20_40_conv_3000_steps_more_info_T.html')
